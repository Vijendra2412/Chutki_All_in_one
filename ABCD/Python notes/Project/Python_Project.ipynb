# %% [markdown]
# # Flipkart Review Scraper

# %%
product=input("Enter the product name:")
# Out:
# Enter the product name:watch

# %%
product
# Out:
# 'watch'

# %%
flipkart_link="https://www.flipkart.com/search?q="+product

# %%
flipkart_link
# Out:
# 'https://www.flipkart.com/search?q=watch'

# %%
from urllib.request import urlopen

# %%
urlopen(flipkart_link)

# %%
site=urlopen(flipkart_link)

# %%
details=site.read()

# %%
details
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
from bs4 import BeautifulSoup as bs

# %%
beautified_details=bs(details,"html.parser")

# %%
beautified_details
# Out:
# <!DOCTYPE html>
# ...

# %%
all_product=(beautified_details.find_all('div',{"class":"_13oc-S"}))

# %%
len(all_product)
# Out:
# 10

# %%
all_product[2]
# Out:
# <div class="_13oc-S _1t9ceu"><div data-id="WATFN6WFBSBYHTCX" style="width:25%"><div class="_1xHGtK _373qXS"><a class="_2UzuFa" href="/lois-caron-lcs-8188-trending-day-date-functioning-boys-analog-watch-men/p/itmc2c03ccfbe758?pid=WATFN6WFBSBYHTCX&amp;lid=LSTWATFN6WFBSBYHTCXHUNGJW&amp;marketplace=FLIPKART&amp;q=watch&amp;store=r18%2Ff13&amp;spotlightTagId=BestsellerId_r18%2Ff13&amp;srno=s_1_9&amp;otracker=search&amp;fm=organic&amp;iid=a85dbee0-cfad-4e4d-b03e-0cb7d34d5ef6.WATFN6WFBSBYHTCX.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=aeej3k5ro00000001689828307998&amp;qH=d2974c96dc96b3f3" rel="noopener noreferrer" target="_blank"><div><div><div class="_3ywSr_" style="padding-top:120.00%"><div class="_312yBx SFzpgZ" style="padding-top:120.00%"><img alt="" class="_2r_T1I" src="https://rukminim2.flixcart.com/image/612/612/k7z3afk0/watch/t/c/x/lcs-8188-lois-caron-original-imafq3k9ztzdkyhe.jpeg?q=70"/></div></div></div></div><div></div><div class="_2hVSre _1DmLJ5 -o7Q4n"><div class="_36FSn5"><svg
# ...

# %%
all_product[2].div.div.a["href"]
# Out:
# '/lois-caron-lcs-8188-trending-day-date-functioning-boys-analog-watch-men/p/itmc2c03ccfbe758?pid=WATFN6WFBSBYHTCX&lid=LSTWATFN6WFBSBYHTCXHUNGJW&marketplace=FLIPKART&q=watch&store=r18%2Ff13&spotlightTagId=BestsellerId_r18%2Ff13&srno=s_1_9&otracker=search&fm=organic&iid=a85dbee0-cfad-4e4d-b03e-0cb7d34d5ef6.WATFN6WFBSBYHTCX.SEARCH&ppt=None&ppn=None&ssid=aeej3k5ro00000001689828307998&qH=d2974c96dc96b3f3'

# %%
lnk="https://www.flipkart.com"+all_product[2].div.div.a["href"]

# %%
single_product=urlopen(lnk)

# %%
single_details=single_product.read()

# %%
single_details
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
details_bt=bs(single_details,"html.parser")

# %%
details_bt
# Out:
# <!DOCTYPE html>
# ...

# %%
Product_name=details_bt.find_all("div",{"class":"aMaAEs"})[0].h1.text

# %%
Product_name
# Out:
# 'LOIS CARON\xa0Trending Day & Date Functioning for Boys Analog Watch  - For Men LCS-8188'

# %%
x=details_bt.find_all("div",{"class":"aMaAEs"})[0]

# %%
price=x.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text

# %%
review_box=details_bt.find_all("div",{"class":"_16PBlm"})

# %%
short_review=review_box[0].div.div.div.p.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 short_review=review_box[0].div.div.div.p.text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
rating=review_box[0].div.div.div.div.text

# %%
name=(review_box[0].div.div).find_all("div",{"class":"row _3n8db9"})[0].div.p.text

# %%
certi=review_box[0].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[0]

# %%
place=review_box[0].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[1].strip()

# %%
review_box[0].find_all("p",{"class":"_2sc7ZR"})[1].text
# Out:
# 'Jan, 2021'

# %%
Product_name,price,name,rating,certi,place,time,short_review
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 Product_name,price,name,rating,certi,place,time,short_review
#
# NameError: name 'time' is not defined

# %%
Product_name=details_bt.find_all("div",{"class":"aMaAEs"})[0].h1.text
price=x.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text
for i in range(len(review_box)-1):
    name=(review_box[i].div.div).find_all("div",{"class":"row _3n8db9"})[0].div.p.text
    certi=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[0]
    place=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[1].strip()
    time=review_box[i].find_all("p",{"class":"_2sc7ZR"})[1].text
    rating=review_box[i].div.div.div.div.text
    short_review=review_box[i].div.div.div.p.text
    
    
    print(Product_name,price,name,rating,certi,place,time,short_review)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       7 time=review_box[i].find_all("p",{"class":"_2sc7ZR"})[1].text
#       8 rating=review_box[i].div.div.div.div.text
# ----> 9 short_review=review_box[i].div.div.div.p.text
#      12 print(Product_name,price,name,rating,certi,place,time,short_review)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for j in range(len(all_product)-3):   
   
    lnk="https://www.flipkart.com"+all_product[j].div.div.a["href"]
    single_product=urlopen(lnk)
    single_details=single_product.read()
    details_bt=bs(single_details,"html.parser")
    Product_name=details_bt.find_all("div",{"class":"aMaAEs"})[0].h1.text
    x=details_bt.find_all("div",{"class":"aMaAEs"})[0]
    price=x.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text
    
    for i in range(len(review_box)-1):
        name=(review_box[i].div.div).find_all("div",{"class":"row _3n8db9"})[0].div.p.text
        certi=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[0]
        place=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[1].strip()
        time=review_box[i].find_all("p",{"class":"_2sc7ZR"})[1].text
        rating=review_box[i].div.div.div.div.text
        short_review=review_box[i].div.div.div.p.text


        print(Product_name,price,name,rating,certi,place,time,short_review)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
#      15 time=review_box[i].find_all("p",{"class":"_2sc7ZR"})[1].text
#      16 rating=review_box[i].div.div.div.div.text
# ---> 17 short_review=review_box[i].div.div.div.p.text
#      20 print(Product_name,price,name,rating,certi,place,time,short_review)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import mysql.connector as conn

# %%
sql=conn.connect(host="localhost",user="root",password="Ranj1296@")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 sql=conn.connect(host="localhost",user="root",password="Ranj1296@")
#
# NameError: name 'conn' is not defined

# %%
cursor=sql.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 cursor=sql.cursor()
#
# NameError: name 'sql' is not defined

# %%
cursor.execute("create database Flipkart_data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 cursor.execute("create database Flipkart_data")
#
# NameError: name 'cursor' is not defined

# %%
cursor.execute("create table flipkart_data.data (product_name varchar(200), price varchar(25), person varchar(50),rating varchar(5),time varchar(20),certification varchar(50),place varchar(100),short_review varchar(200))")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 cursor.execute("create table flipkart_data.data (product_name varchar(200), price varchar(25), person varchar(50),rating varchar(5),time varchar(20),certification varchar(50),place varchar(100),short_review varchar(200))")
#
# NameError: name 'cursor' is not defined

# %%
sql.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 sql.close()
#
# NameError: name 'sql' is not defined

# %%
for j in range(len(all_product)-3):   
   
    lnk="https://www.flipkart.com"+all_product[j].div.div.a["href"]
    single_product=urlopen(lnk)
    single_details=single_product.read()
    details_bt=bs(single_details,"html.parser")
    Product_name=details_bt.find_all("div",{"class":"aMaAEs"})[0].h1.text
    x=details_bt.find_all("div",{"class":"aMaAEs"})[0]
    price=x.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text
    
    for i in range(len(review_box)-1):
        name=(review_box[i].div.div).find_all("div",{"class":"row _3n8db9"})[0].div.p.text
        certi=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[0]
        place=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[1].strip()
        time=review_box[i].find_all("p",{"class":"_2sc7ZR"})[1].text
        rating=review_box[i].div.div.div.div.text
        short_review=review_box[i].div.div.div.p.text
        
        sql=conn.connect(host="localhost",user="root",password="Ranj1296@")
        cursor=sql.cursor()
        s="insert into flipkart_data.data values(%s,%s,%s,%s,%s,%s,%s,%s)"
        v=(Product_name,price,name,rating,time,certi,place,short_review)
        cursor.execute(s,v)
        sql.commit()
        sql.close()


        #print(Product_name,price,name,rating,certi,place,time,short_review)

# %%
for j in range(len(all_product)-3):   
   
    lnk="https://www.flipkart.com"+all_product[j].div.div.a["href"]
    single_product=urlopen(lnk)
    single_details=single_product.read()
    details_bt=bs(single_details,"html.parser")
    try:
        Product_name=details_bt.find_all("div",{"class":"aMaAEs"})[0].h1.text
    except:
        Product_name="NO product"
    try:
        x=details_bt.find_all("div",{"class":"aMaAEs"})[0]
        price=x.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text
    except:
        price="NO price"
    
    for i in range(len(review_box)-1):
        try:
            name=(review_box[i].div.div).find_all("div",{"class":"row _3n8db9"})[0].div.p.text
        except:
            name="No name"
        try:
            certi=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[0]
        except:
            certi="No certi"
        try:
            place=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[1].strip()
        except:
            place="No place"
        try:
            time=review_box[i].find_all("p",{"class":"_2sc7ZR"})[1].text
        except:
            time="no time"
        try:
            rating=review_box[i].div.div.div.div.text
        except:
            rating="No Rating"
        try:
            short_review=review_box[i].div.div.div.p.text
        except:
            short_review="No review"
            
        print(Product_name,price,name,rating,certi,place,time,short_review)  
        file=open(f"{product}.csv","a")
        file.write(f"{name},{certi},{place},{time},{rating},{short_review}\n")
        file.close()

# %%
file=open(f"{product}.csv","a")
file.write("Name, Certification, Place,Time, Rating,Short_review \n")
file.close()

# %%
import pandas as pd

# %%
df=pd.read_csv("tv.csv",)

# %%
pd.reset_index(df)

# %%
df

# %%
# Flipkart web scrapper
site="flipkart"
product=input("Enter the product name:")
flipkart_link="https://www.flipkart.com/search?q="+product
from urllib.request import urlopen
details=(urlopen(flipkart_link)).read()
from bs4 import BeautifulSoup as bs
beautified_details=bs(details,"html.parser")
all_product=(beautified_details.find_all('div',{"class":"_13oc-S"}))

file=open(f"{product}.csv","a")
file.write("Name, Certification, Place,Time, Rating,Short_review \n")
file.close()

import mysql.connector as conn
sql=conn.connect(host="localhost",user="root",password="Ranj1296@")
cursor=sql.cursor()
cursor.execute(f"create database if not exists {site}")
cursor.execute(f"create table if not exists {site}.{product} (product_name varchar(200), price varchar(25), person varchar(50),rating varchar(5),time varchar(20),certification varchar(50),place varchar(100),short_review varchar(200))")
sql.close()
count=0
for j in range(len(all_product)-3):   
   
    lnk="https://www.flipkart.com"+all_product[j].div.div.a["href"]
    single_product=urlopen(lnk)
    single_details=single_product.read()
    details_bt=bs(single_details,"html.parser")
    try:
        Product_name=(details_bt.find_all("div",{"class":"aMaAEs"})[0].h1.text)[0:110]
    except:
        Product_name="NO product"
    try:
        x=details_bt.find_all("div",{"class":"aMaAEs"})[0]
        price=x.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text
        if ","in price:
            price=price.replace(",","")
    except:
        price="NO price"
    review_box=details_bt.find_all("div",{"class":"_16PBlm"})
    
    for i in range(len(review_box)-1):
        try:
            name=(review_box[i].div.div).find_all("div",{"class":"row _3n8db9"})[0].div.p.text
        except:
            name="No name"
        try:
            certi=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[0]
        except:
            certi="No certi"
        try:
            place=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[1].strip()
        except:
            place="No place"
        try:
            time=review_box[i].find_all("p",{"class":"_2sc7ZR"})[1].text
            if "," in time:
                time=time.replace(","," ")
                
        except:
            time="no time"
        try:
            rating=review_box[i].div.div.div.div.text[0:3]
        except:
            rating="No Rating"
        try:
            short_review=review_box[i].div.div.div.p.text
        except:
            short_review="No review"
            
        print(Product_name,price,name,rating,certi,place,time,short_review)  
        file=open(f"{product}.csv","a")
        file.write(f"{name},{certi},{place},{time},{rating},{short_review}\n")
        file.close()
        
        sql=conn.connect(host="localhost",user="root",password="Ranj1296@")
        cursor=sql.cursor()
        s=f"insert into {site}.{product} values(%s,%s,%s,%s,%s,%s,%s,%s)"
        v=(Product_name,price,name,rating,time,certi,place,short_review)
        cursor.execute(s,v)
        sql.commit()
        sql.close()
        count+=1
print("Number of data is:",count)
# Out:
# Enter the product name:watch
# Praizy Times New Fashion Watch for Men and Boys Premium Collection King Bracelet Watch Combo Analog Watch  - F ₹225 Flipkart Customer 4ni Certified Buyer Ratnapur Mar  2022 No review
# Praizy Times New Fashion Watch for Men and Boys Premium Collection King Bracelet Watch Combo Analog Watch  - F ₹225 Bapuji Dash 5Wa Certified Buyer Nayagarh District 4 months ago No review
# SONATA Volt Analog Watch  - For Men 77085PP03 ₹407 Aadesh Ghagare 5da Certified Buyer Nagpur Oct  2019 No review
# SONATA Volt Analog Watch  - For Men 77085PP03 ₹407 Shawez Ahmad 5It Certified Buyer Varanasi Jun  2020 No review
# Fastrack Minimalists Analog Watch  - For Men 38024PP25 ₹805 Arun Chame 5My Certified Buyer Ahmadpur Sep  2019 No review
# Fastrack Minimalists Analog Watch  - For Men 38024PP25 ₹805 Flipkart Customer 4Ve Certified Buyer Prakasam District Mar  2020 No review
# ...

# %%
# Flipkart web scrapper
site="flipkart"
product=input("Enter the product name:")
flipkart_link="https://www.flipkart.com/search?q="+product
from urllib.request import urlopen
details=(urlopen(flipkart_link)).read()
from bs4 import BeautifulSoup as bs
beautified_details=bs(details,"html.parser")
all_product=(beautified_details.find_all('div',{"class":"_13oc-S"}))

file=open(f"{product}.csv","a")
file.write("Name, Certification, Place,Time, Rating,Short_review \n")
file.close()

import mysql.connector as conn
sql=conn.connect(host="localhost",user="root",password="Ranj1296@")
cursor=sql.cursor()
cursor.execute(f"create database if not exists {site}")
cursor.execute(f"create table if not exists {site}.{product} (product_name varchar(200), price varchar(25), person varchar(50),rating varchar(5),time varchar(20),certification varchar(50),place varchar(100),short_review varchar(200))")
sql.close()
count=0
for j in range(len(all_product)-3):   
   
    lnk="https://www.flipkart.com"+all_product[j].div.div.a["href"]
    single_product=urlopen(lnk)
    single_details=single_product.read()
    details_bt=bs(single_details,"html.parser")
    try:
        Product_name=(details_bt.find_all("div",{"class":"aMaAEs"})[0].h1.text)[0:110]
    except:
        Product_name="NO product"
    try:
        x=details_bt.find_all("div",{"class":"aMaAEs"})[0]
        price=x.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text
        if ","in price:
            price=price.replace(",","")
    except:
        price="NO price"
    review_box=details_bt.find_all("div",{"class":"_16PBlm"})
    
    for i in range(len(review_box)-1):
        try:
            name=(review_box[i].div.div).find_all("div",{"class":"row _3n8db9"})[0].div.p.text
        except:
            name="No name"
        try:
            certi=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[0]
        except:
            certi="No certi"
        try:
            place=review_box[i].find_all("p",{"class":"_2mcZGG"})[0].text.split(",")[1].strip()
        except:
            place="No place"
        try:
            time=review_box[i].find_all("p",{"class":"_2sc7ZR"})[1].text
            if "," in time:
                time=time.replace(","," ")
                
        except:
            time="no time"
        try:
            rating=review_box[i].div.div.div.div.text[0:3]
        except:
            rating="No Rating"
        try:
            short_review=review_box[i].div.div.div.p.text
        except:
            short_review="No review"
            
        print(Product_name,price,name,rating,certi,place,time,short_review)  
        file=open(f"{product}.csv","a")
        file.write(f"{name},{certi},{place},{time},{rating},{short_review}\n")
        file.close()
        
        sql=conn.connect(host="localhost",user="root",password="Ranj1296@")
        cursor=sql.cursor()
        s=f"insert into {site}.{product} values(%s,%s,%s,%s,%s,%s,%s,%s)"
        v=(Product_name,price,name,rating,time,certi,place,short_review)
        cursor.execute(s,v)
        sql.commit()
        sql.close()
        count+=1
print("Number of data is:",count)
# Out:
# Enter the product name:watch
# LOIS CARON Trending Day & Date Functioning for Boys Analog Watch  - For Men LCS-8188 ₹288 SAMBHUNATH  CHOWDHURY 5Fu Certified Buyer Bansberia Jan  2021 No review
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:611, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     610         query = query.encode("utf-8")
# --> 611     self._cmysql.query(
#     612         query,
#     613         raw=raw,
#     614         buffered=buffered,
#     615         raw_as_string=raw_as_string,
#     616         query_attrs=self._query_attrs,
#     617     )
#     618 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Column count doesn't match value count at row 1
#
# The above exception was the direct cause of the following exception:
#
# ...
